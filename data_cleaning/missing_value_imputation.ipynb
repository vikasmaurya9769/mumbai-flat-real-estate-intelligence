# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r'E:\Mumbai Flat Real Estate Intelligence\datasets\mumbai_prperties_outlier_treated.csv')

# %%
df['major_location'].value_counts().shape
# Out:
# (115,)

# %% [markdown]
# ### most missing value is already handle in feature engg

# %%
df.isnull().sum()
# Out:
# price               1
# bedrooms            0
# bathrooms           0
# balcony             0
# property_age       17
# major_location      0
# built_up_area       0
# furnishing_type     0
# dtype: int64

# %%
df.sample()
# Out:
#       price  bedrooms  bathrooms balcony         property_age major_location  \
# 8898    7.7         3          3       2  recent construction    Bandra East
#
#       built_up_area furnishing_type
# 8898         1850.0       Furnished

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [price, bedrooms, bathrooms, balcony, property_age, major_location, built_up_area, furnishing_type]
# Index: []

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# price               1
# bedrooms            0
# bathrooms           0
# balcony             0
# property_age       17
# major_location      0
# built_up_area       0
# furnishing_type     0
# dtype: int64

# %%
df['property_age'].value_counts()
# Out:
# property_age
# recent construction    3731
# new construction       1983
# modern property        1316
# Relatively New          965
# New Property            492
# Old Property            356
# Moderately Old          335
# mid age property        310
# Undefined               138
# old propert               6
# Name: count, dtype: int64

# %%
df['property_age'].fillna("Undefined", inplace=True)
# Out:
# C:\Users\vikas\AppData\Local\Temp\ipykernel_16388\1597376796.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['property_age'].fillna("Undefined", inplace=True)

# %%
def mode_based_imputation(row):
    if row['property_age'] == 'Undefined':
        mode_value = df[(df['major_location'] == row['major_location'])]['property_age'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['property_age']

# %%
df['property_age'] = df.apply(mode_based_imputation,axis=1)

# %%
df['property_age'].value_counts()
# Out:
# property_age
# recent construction    3748
# new construction       1986
# modern property        1316
# Relatively New          989
# New Property            496
# Old Property            363
# Moderately Old          349
# mid age property        310
# Undefined                86
# old propert               6
# Name: count, dtype: int64

# %%
def mode_based_imputation3(row):
    if row['property_age'] == 'Undefined':
        mode_value = df['property_age'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['property_age']

# %%
df['property_age'] = df.apply(mode_based_imputation3,axis=1)

# %%
df['property_age'].value_counts()
# Out:
# property_age
# recent construction    3834
# new construction       1986
# modern property        1316
# Relatively New          989
# New Property            496
# Old Property            363
# Moderately Old          349
# mid age property        310
# old propert               6
# Name: count, dtype: int64

# %%
df['property_age'] = df['property_age'].replace({
    'old propert': 'Old Property',
    'mid age property': 'Mid Age Property'
})

# %%
df['property_age'] = df['property_age'].str.lower().str.strip()

# %%
mapping = {
    'recent construction': 'New_property',
    'new construction': 'New_property',
    'new property': 'New_property',

    'relatively new': 'Relatively New',
    'modern property': 'Relatively New',

    'moderately old': 'Mid Age',
    'mid age property': 'Mid Age',

    'old property': 'Old',

    'undefined': 'Undefined'
}

# %%
df['property_age'] = df['property_age'].map(mapping)

# %%
df['property_age'].value_counts()
# Out:
# property_age
# New_property      6316
# Relatively New    2305
# Mid Age            659
# Old                369
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# price              1
# bedrooms           0
# bathrooms          0
# balcony            0
# property_age       0
# major_location     0
# built_up_area      0
# furnishing_type    0
# dtype: int64

# %%
df[df['price'].isnull()]
# Out:
#       price  bedrooms  bathrooms balcony    property_age major_location  \
# 9648    NaN         3          4       2  Relatively New   Malabar Hill
#
#       built_up_area furnishing_type
# 9648         2375.0     Unfurnished

# %%
df.drop(9648, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (9648, 8)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (9615, 8)

# %%
df[df['price']<0.2]
# Out:
#    price  bedrooms  bathrooms balcony  property_age   major_location  \
# 0   0.08         1          1       0  New_property          Palghar
# 1   0.17         1          1       2  New_property  Nalasopara West
# 2   0.18         1          1       0  New_property           others
# 3   0.18         1          1       2  New_property          Palghar
# 4   0.18         1          1       2  New_property          Palghar
# 5   0.18         1          2       1  New_property          Palghar
# 6   0.19         1          1       2  New_property          Palghar
#
#    built_up_area furnishing_type
# 0          540.0       Furnished
# 1          550.0       Furnished
# 2          665.0       Furnished
# 3          630.0       Furnished
# 4          630.0     Unfurnished
# 5          630.0       Furnished
# 6          630.0     Unfurnished

# %%
df.drop(0, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df['furnishing_type'].value_counts()
# Out:
# furnishing_type
# Furnished      5453
# Unfurnished    4161
# Name: count, dtype: int64

# %%
df.to_csv('mumbai_properties_missing_value_imputation.csv',index=False)
