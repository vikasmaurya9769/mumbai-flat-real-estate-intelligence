# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVR

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor
import category_encoders as ce
from sklearn.model_selection import GridSearchCV, KFold

# %%
df = pd.read_csv(R'E:\Mumbai Flat Real Estate Intelligence\datasets\mumbai_properties_post_feature_selection_v2.csv')

# %%
df.head()
# Out:
#    price  bedrooms  bathrooms balcony  property_age   major_location  \
# 0   0.17         1          1       2  New_property  Nalasopara West
# 1   0.18         1          1       0  New_property           others
# 2   0.18         1          1       2  New_property          Palghar
# 3   0.18         1          1       2  New_property          Palghar
# 4   0.18         1          2       1  New_property          Palghar
#
#    built_up_area furnishing_type
# 0          550.0       Furnished
# 1          665.0       Furnished
# 2          630.0       Furnished
# 3          630.0     Unfurnished
# 4          630.0       Furnished

# %%
df['furnishing_type'].value_counts()
# Out:
# furnishing_type
# Furnished      5453
# Unfurnished    4161
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (9614, 8)

# %%
df = df[df['major_location'] != 'Vakola']

# %%
df.shape
# Out:
# (9611, 8)

# %%
# df = df[df['price']<18]

# %%
# df.shape

# %%
X = df.drop(columns=['price'])
y = df['price']

# %%
# Applying the log1p transformation to the target variable
y_transformed = np.log1p(y)

# %% [markdown]
# ### Ordinal Encoding

# %%
columns_to_encode = ['major_location',  'property_age', 'balcony','furnishing_type']

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedrooms', 'bathrooms', 'built_up_area']),
        ('cat', OrdinalEncoder(), columns_to_encode)
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean(),scores.std()
# Out:
# (np.float64(0.7384415010872983), np.float64(0.013974063061669746))

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedrooms', 'bathrooms',
#                                                    'built_up_area']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['major_location',
#                                                    'property_age', 'balcony',
#                                                    'furnishing_type'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 1.0760850631621757

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_output
# Out:
# [['linear_reg', np.float64(0.7384415010872983), 1.0760850631621757],
#  ['svr', np.float64(0.7446173229027798), 1.0255749457664811],
#  ['ridge', np.float64(0.7384417618897658), 1.076046094685717],
#  ['LASSO', np.float64(0.018147290612791356), 1.907486662374778],
#  ['decision tree', np.float64(0.8163529750867635), 0.777763129751163],
#  ['random forest', np.float64(0.8965815913749928), 0.651841472720792],
#  ['extra trees', np.float64(0.8562481926909742), 0.7425385062536007],
#  ['gradient boosting', np.float64(0.8799930831369865), 0.7267691050287263],
#  ['adaboost', np.float64(0.7356898907592615), 1.0647648726786139],
#  ['mlp', np.float64(0.774728871682059), 0.9311601678328532],
#  ['xgboost', np.float64(0.9236356664535151), 0.5670053339024663]]

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 10            xgboost  0.923636  0.567005
# 5       random forest  0.896582  0.651841
# 7   gradient boosting  0.879993  0.726769
# 6         extra trees  0.856248  0.742539
# 4       decision tree  0.816353  0.777763
# 9                 mlp  0.774729  0.931160
# 1                 svr  0.744617  1.025575
# 8            adaboost  0.735690  1.064765
# 2               ridge  0.738442  1.076046
# 0          linear_reg  0.738442  1.076085
# 3               LASSO  0.018147  1.907487

# %% [markdown]
# ### OHE

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedrooms', 'bathrooms', 'built_up_area']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first'),['major_location','property_age','furnishing_type'])
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean()
# Out:
# np.float64(0.9126758226051189)

# %%
scores.std()
# Out:
# np.float64(0.00556185924412332)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedrooms', 'bathrooms',
#                                                    'built_up_area']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['major_location',
#                                                    'property_age', 'balcony',
#                                                    'furnishing_type']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['major_location',
#                                                    'property_age',
#                                                    'furnishing_type'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 0.6368726471167551

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 6         extra trees  0.916159  0.566067
# 9                 mlp  0.919185  0.570736
# 10            xgboost  0.924092  0.574965
# 5       random forest  0.915026  0.579329
# 2               ridge  0.912170  0.636194
# 0          linear_reg  0.912676  0.636873
# 4       decision tree  0.860215  0.693673
# 7   gradient boosting  0.880794  0.713258
# 1                 svr  0.785682  0.963674
# 8            adaboost  0.742037  1.026657
# 3               LASSO  0.018147  1.907487

# %% [markdown]
# ### OneHotEncoding With PCA

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedrooms', 'bathrooms', 'built_up_area']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),['major_location','property_age'])
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('pca', PCA(n_components=0.95)),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean()
# Out:
# np.float64(0.020503307020318308)

# %%
scores.std()
# Out:
# np.float64(0.008235909844130708)

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('pca', PCA(n_components=0.95)),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 5       random forest  0.686651  1.079481
# 6         extra trees  0.651676  1.119145
# 4       decision tree  0.589933  1.228788
# 10            xgboost  0.613427  1.260955
# 7   gradient boosting  0.593137  1.307499
# 8            adaboost  0.249717  1.750911
# 1                 svr  0.071194  1.824727
# 9                 mlp  0.076866  1.882633
# 2               ridge  0.020503  1.905793
# 0          linear_reg  0.020503  1.905793
# 3               LASSO  0.018190  1.907461

# %% [markdown]
# ### Target Encoder

# %%
import category_encoders as ce

# %%
columns_to_encode = ['major_location', 'balcony', 'property_age', 'furnishing_type']

# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedrooms', 'bathrooms', 'built_up_area']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),['property_age']),
        ('target_enc', ce.TargetEncoder(), ['major_location'])
    ], 
    remainder='passthrough'
)

# %%
# !pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (2.9.0)
# Requirement already satisfied: numpy>=1.14.0 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from category_encoders) (2.3.5)
# Requirement already satisfied: pandas>=1.0.5 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from category_encoders) (2.3.3)
# Requirement already satisfied: patsy>=0.5.1 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: scikit-learn>=1.6.0 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from category_encoders) (1.7.2)
# Requirement already satisfied: scipy>=1.0.0 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from category_encoders) (1.16.3)
# Requirement already satisfied: statsmodels>=0.9.0 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from category_encoders) (0.14.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: six>=1.5 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (25.0)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean(),scores.std()
# Out:
# (np.float64(0.8907256650300992), np.float64(0.008092702807362219))

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 10            xgboost  0.930499  0.539400
# 6         extra trees  0.926101  0.541827
# 5       random forest  0.928034  0.546414
# 7   gradient boosting  0.917957  0.592108
# 4       decision tree  0.877464  0.669979
# 9                 mlp  0.893293  0.698419
# 0          linear_reg  0.890726  0.700720
# 2               ridge  0.890727  0.700744
# 1                 svr  0.862140  0.793409
# 8            adaboost  0.856102  0.795600
# 3               LASSO  0.018147  1.907487

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
df.head()
# Out:
#    price  bedrooms  bathrooms balcony  property_age   major_location  \
# 0   0.17         1          1       2  New_property  Nalasopara West
# 1   0.18         1          1       0  New_property           others
# 2   0.18         1          1       2  New_property          Palghar
# 3   0.18         1          1       2  New_property          Palghar
# 4   0.18         1          2       1  New_property          Palghar
#
#    built_up_area furnishing_type
# 0          550.0       Furnished
# 1          665.0       Furnished
# 2          630.0       Furnished
# 3          630.0     Unfurnished
# 4          630.0       Furnished

# %%
param_grid = {
    'regressor__n_estimators': [50, 100, 150],
    'regressor__max_depth': [None, 10, 20, 25, 30],
    'regressor__min_samples_split': [2, 5, 10],
    'regressor__min_samples_leaf': [1, 2, 4],
    'regressor__max_features': ['auto', 'sqrt'],
    'regressor__max_samples': [0.5, 0.75, 1.0]
}

# %%
columns_to_encode = [ 'balcony', 'furnishing_type']

# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedrooms', 'bathrooms', 'built_up_area']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),['property_age']),
        ('target_enc', ce.TargetEncoder(), ['major_location'])
    ], 
    remainder='passthrough'
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor())
])

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# %%
search = GridSearchCV(pipeline, param_grid, cv=kfold, scoring='r2', n_jobs=-1, verbose=4)

# %%
search.fit(X, y_transformed)
# Out:
# Fitting 10 folds for each of 810 candidates, totalling 8100 fits
# e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\model_selection\_validation.py:516: FitFailedWarning:
# 4050 fits failed out of a total of 8100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1685 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\pipeline.py", line 663, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 2365 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\pipeline.py", line 663, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\model_selection\_search.py:1135: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.92268929 0.92405117 0.92427403
#  0.92232679 0.92262232 0.9230822  0.91896325 0.92009989 0.91992324
#  0.91991357 0.92161572 0.92104587 0.92034793 0.92057075 0.92103356
#  0.9180207  0.91844845 0.91867576 0.91578363 0.91610298 0.91634378
#  0.91608119 0.91631197 0.91670909 0.91585787 0.91569572 0.91608734
#  0.92435901 0.92478621 0.92534639 0.92359731 0.92436296 0.92460688
#  0.92114618 0.92186426 0.92209364 0.9222315  0.9231764  0.9231429
#  0.9217543  0.92252717 0.92278532 0.92034473 0.9205318  0.92118446
#  0.91810145 0.91900638 0.9190087  0.91806112 0.91867747 0.9188329
#  0.91797278 0.91816016 0.91846891 0.9240508  0.92438458 0.92494588
#  0.92458435 0.92486672 0.92558221 0.92251904 0.92327191 0.92348199
#  0.92343656 0.92425802 0.92429335 0.92305589 0.92377242 0.92383877
#  0.92153303 0.92228924 0.92235429 0.91962395 0.92012748 0.92020465
#  0.92002763 0.91987746 0.92023781 0.91953162 0.91945707 0.91996673
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.91666232 0.91659676 0.9166179
#  0.91512239 0.91627454 0.91639009 0.91469838 0.91491096 0.91486013
#  0.91518506 0.9156731  0.91566703 0.91496492 0.91520803 0.91537828
#  0.91390142 0.91429466 0.91427469 0.9129609  0.91290382 0.91313643
#  0.91294097 0.91343202 0.91321928 0.91262237 0.91277286 0.91318028
#  0.91693326 0.91730553 0.91739014 0.91624786 0.91697468 0.91683782
#  0.91489309 0.91572111 0.91594154 0.91631208 0.91664636 0.9163773
#  0.91622406 0.91641421 0.91639196 0.91521234 0.91527062 0.91570917
#  0.91459526 0.91441266 0.91477434 0.91410653 0.91456824 0.91496551
#  0.91425257 0.91438469 0.91430029 0.91706479 0.91766345 0.9181596
#  0.91637804 0.9174289  0.91757816 0.91576106 0.91676398 0.91645744
#  0.91709323 0.9173909  0.91702844 0.91651076 0.91716901 0.91715363
#  0.91541749 0.91656789 0.91636669 0.91437915 0.91545207 0.91543204
#  0.91497733 0.91543767 0.91566633 0.91429273 0.91503119 0.91531796
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.92320797 0.92420671 0.92425203
#  0.92178352 0.92258392 0.92290665 0.91922178 0.92011623 0.92009318
#  0.92056696 0.92139587 0.92149314 0.9201879  0.92057431 0.92085148
#  0.91795227 0.91836863 0.9186053  0.9162909  0.91607754 0.91652865
#  0.91605174 0.91609174 0.91626756 0.91497071 0.91587221 0.91586056
#  0.92400526 0.92486446 0.92526329 0.92403589 0.92437378 0.92461563
#  0.92149674 0.92182904 0.9221769  0.92276621 0.92293397 0.92333925
#  0.92225929 0.92270632 0.92302747 0.92018351 0.92061569 0.92111969
#  0.91832023 0.91893352 0.91887588 0.91810923 0.91864927 0.91877178
#  0.91816547 0.91834838 0.9184813  0.92378698 0.92519381 0.92520723
#  0.92469047 0.9250967  0.92556959 0.92271861 0.92316927 0.92334559
#  0.9232721  0.92418841 0.92410694 0.92333993 0.92415874 0.92387256
#  0.92195306 0.92212948 0.92250625 0.91943086 0.92012837 0.92017082
#  0.91931101 0.92025162 0.92022961 0.91883827 0.91967948 0.91982905
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.92276293 0.92338751 0.92436324
#  0.92103975 0.92280543 0.92267744 0.91868267 0.91997441 0.91999933
#  0.92064044 0.92113484 0.92135008 0.92006029 0.92074521 0.9208546
#  0.91752307 0.91873518 0.91874487 0.91583385 0.91635046 0.91632404
#  0.91536019 0.91598619 0.9167006  0.91539276 0.91581244 0.91601631
#  0.92410242 0.92486314 0.9247936  0.92421774 0.92433299 0.92465425
#  0.92149122 0.92218449 0.92202485 0.92228291 0.92309489 0.92305004
#  0.92177928 0.92247463 0.92313385 0.92060197 0.92089596 0.92100326
#  0.91832551 0.9185444  0.91902275 0.918271   0.91865502 0.91893967
#  0.91785092 0.91815784 0.91872883 0.92380112 0.92438919 0.92512051
#  0.92427307 0.92505707 0.92522348 0.92295996 0.92315923 0.92349021
#  0.92339671 0.92408523 0.92422743 0.9235746  0.92364018 0.92391079
#  0.92156015 0.92184052 0.92236089 0.91995689 0.92036847 0.92026905
#  0.91979939 0.92031748 0.92023911 0.91894163 0.91974205 0.91996947
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.92276269 0.92350915 0.92450957
#  0.92195388 0.92246764 0.92289197 0.91901102 0.91964256 0.92006295
#  0.92102648 0.9210668  0.92134103 0.91945515 0.92064589 0.92084334
#  0.91826441 0.91792532 0.9189217  0.91589123 0.91655754 0.91650768
#  0.91580492 0.91624059 0.91650097 0.91575217 0.91558351 0.91600158
#  0.92396272 0.92463248 0.92494814 0.92344893 0.92377717 0.92444047
#  0.92133483 0.92201234 0.92210178 0.92208308 0.92319766 0.9233207
#  0.92195306 0.9227642  0.92296909 0.91976106 0.9205137  0.92092237
#  0.91845252 0.91861893 0.91907263 0.91801566 0.91869086 0.9188212
#  0.91835034 0.91802906 0.91867033 0.92346049 0.92475031 0.92487378
#  0.92433165 0.92486031 0.92543787 0.92229494 0.92341361 0.92340291
#  0.92354511 0.92425755 0.92422337 0.92313988 0.92345564 0.92402436
#  0.92146065 0.9222845  0.92210975 0.91959866 0.92029193 0.92049706
#  0.91964074 0.9199474  0.9201007  0.91898257 0.91983499 0.91967778]
#   warnings.warn(
# GridSearchCV(cv=KFold(n_splits=10, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['bedrooms',
#                                                                           'bathrooms',
#                                                                           'built_up_area']),
#                                                                         ('cat',
#                                                                          OrdinalEncoder(),
#                                                                          ['balcony',
#                                                                           'furnishing_type']),
#                                                                         ('cat1',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        sparse_output=False),
#                                                                          ['property_...
#                                                                          ['major_location'])])),
#                                        ('regressor', RandomForestRegressor())]),
#              n_jobs=-1,
#              param_grid={'regressor__max_depth': [None, 10, 20, 25, 30],
#                          'regressor__max_features': ['auto', 'sqrt'],
#                          'regressor__max_samples': [0.5, 0.75, 1.0],
#                          'regressor__min_samples_leaf': [1, 2, 4],
#                          'regressor__min_samples_split': [2, 5, 10],
#                          'regressor__n_estimators': [50, 100, 150]},
#              scoring='r2', verbose=4)

# %%
final_pipe = search.best_estimator_

# %%
search.best_params_
# Out:
# {'regressor__max_depth': None,
#  'regressor__max_features': 'sqrt',
#  'regressor__max_samples': 1.0,
#  'regressor__min_samples_leaf': 1,
#  'regressor__min_samples_split': 5,
#  'regressor__n_estimators': 150}

# %%
search.best_score_
# Out:
# np.float64(0.9255822117592138)

# %%
final_pipe.fit(X,y_transformed)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedrooms', 'bathrooms',
#                                                    'built_up_area']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['balcony',
#                                                    'furnishing_type']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['property_age']),
#                                                  ('target_enc', TargetEncoder(),
#                                                   ['major_location'])])),
#                 ('regressor',
#                  RandomForestRegressor(max_features='sqrt', max_samples=1.0,
#                                        min_samples_split=5,
#                                        n_estimators=150))])

# %%
y_pred = final_pipe.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 0.33176703606975905

# %% [markdown]
# best selected model

# %%
numeric_cols = ['bedrooms', 'bathrooms', 'built_up_area']
onehot_cols = ['balcony', 'property_age', 'furnishing_|type']
target_cols = ['major_location']

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_cols),
        ('cat_onehot', OneHotEncoder(drop='first', sparse_output=False), onehot_cols),
        ('target', ce.TargetEncoder(), target_cols)
    ],
    remainder='drop'
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor())
])

# %%
param_grid = {
    'regressor__n_estimators': [100],
    'regressor__max_depth': [None, 10, 20, 25, 30],
    'regressor__min_samples_split': [2, 5, 10],
    'regressor__min_samples_leaf': [1, 2, 4],
    'regressor__max_features': ['auto', 'sqrt'],
    'regressor__max_samples': [0.5, 0.75, 1.0]
}

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

search = GridSearchCV(
    pipeline,
    param_grid,
    cv=kfold,
    scoring='r2',
    n_jobs=-1,
    verbose=4
)

# %%
# search.fit(X, y_transformed)

# %%
final_pipe = search.best_estimator_

# %%
y_pred = final_pipe.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mae = mean_absolute_error(np.expm1(y_test), y_pred)

# %%
print("Best Params:", search.best_params_)
print("Best R2 Score:", search.best_score_)
print("MAE:", mean_absolute_error(np.expm1(y_test), y_pred))
# Out:
# Best Params: {'regressor__max_depth': 20, 'regressor__max_features': 'sqrt', 'regressor__max_samples': 1.0, 'regressor__min_samples_leaf': 1, 'regressor__min_samples_split': 2, 'regressor__n_estimators': 300}
# Best R2 Score: 0.9227966512910777
# MAE: 0.243559218444499

# %% [markdown]
# ### exporting pkl

# %%
import pickle

with open("pipeline.pkl", "wb") as file:
    pickle.dump(final_pipe, file)

# %%
with open('df.pkl', 'wb') as file:
    pickle.dump(X, file)

# %%
X
# Out:
#       bedrooms  bathrooms balcony    property_age   major_location  \
# 0            1          1       2    New_property  Nalasopara West
# 1            1          1       0    New_property           others
# 2            1          1       2    New_property          Palghar
# 3            1          1       2    New_property          Palghar
# 4            1          2       1    New_property          Palghar
# ...        ...        ...     ...             ...              ...
# 9609         5          5       0             Old     Malabar Hill
# 9610         5          5       0         Mid Age     Malabar Hill
# 9611         5          6       1             Old     Malabar Hill
# 9612         6          4       3         Mid Age      Lower Parel
# 9613         4          4       2  Relatively New     Malabar Hill
#
#       built_up_area furnishing_type
# 0             550.0       Furnished
# 1             665.0       Furnished
# 2             630.0       Furnished
# 3             630.0     Unfurnished
# 4             630.0       Furnished
# ...             ...             ...
# 9609         3699.0     Unfurnished
# 9610         3181.0       Furnished
# 9611         2850.0       Furnished
# 9612         5042.0       Furnished
# 9613         2917.0     Unfurnished
#
# [9611 rows x 7 columns]

# %%
X.shape
# Out:
# (9611, 7)

# %%
df.to_csv('mumbai_properties_final.csv', index=False)

# %% [markdown]
# ### Trying out the predictions

# %%
X.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'balcony', 'property_age', 'major_location',
#        'built_up_area', 'furnishing_type'],
#       dtype='object')

# %%
X.iloc[0].values
# Out:
# array([np.int64(1), np.int64(1), '2', 'New_property', 'Nalasopara West',
#        np.float64(550.0), 'Furnished'], dtype=object)

# %%
data = [[ 2, 2, '0', 'Mid Age', 'Mulund West', 650,  'Unfurnished']]
columns = ['bedrooms', 'bathrooms', 'balcony', 'property_age', 'major_location',
       'built_up_area',  'furnishing_type']

# Convert to DataFrame
one_df = pd.DataFrame(data, columns=columns)

one_df
# Out:
#    bedrooms  bathrooms balcony property_age major_location  built_up_area  \
# 0         2          2       0      Mid Age    Mulund West            650
#
#   furnishing_type
# 0     Unfurnished

# %%
np.expm1(final_pipe.predict(one_df))
# Out:
# array([1.76952293])

# %%
X.dtypes
# Out:
# bedrooms             int64
# bathrooms            int64
# balcony             object
# property_age        object
# major_location      object
# built_up_area      float64
# furnishing_type     object
# dtype: object

# %%
sorted(X['major_location'].unique().tolist())
# Out:
# ['Agripada',
#  'Andheri East',
#  'Andheri West',
#  'Bandra East',
#  'Bandra West',
#  'Bhandup East',
#  'Bhandup West',
#  'Bhayandar East',
#  'Bhayandar West',
#  'Bhoiwada',
#  'Boisar',
#  'Bolinj',
#  'Borivali East',
#  'Borivali West',
#  'Byculla',
#  'Chakala',
#  'Chembur',
#  'Chikhal Dongari',
#  'Churchgate',
#  'Colaba',
#  'Cuffe Parade',
#  'Cumballa Hill',
#  'Dadar East',
#  'Dadar West',
#  'Dahisar',
#  'Dahisar East',
#  'Dahisar West',
#  'Dattapada',
#  'Deonar',
#  'Evershine Nagar',
#  'Gandhi Nagar',
#  'Ghatkopar East',
#  'Ghatkopar West',
#  'Girgaon',
#  'Goregaon',
#  'Goregaon East',
#  'Goregaon West',
#  'Govandi',
#  'Hindu Colony',
#  'Hmpl Surya Nagar',
#  'Jogeshwari East',
#  'Jogeshwari West',
#  'Juhu',
#  'Juhu Scheme',
#  'Jvpd Scheme',
#  'Kala Nagar',
#  'Kamathipura',
#  'Kanchpada',
#  'Kandivali East',
#  'Kandivali West',
#  'Kanjurmarg East',
#  'Kanjurmarg West',
#  'Kashimira',
#  'Khar West',
#  'Kherwadi',
#  'Kurla East',
#  'Kurla West',
#  'Lower Parel',
#  'Lower Parel East',
#  'Lower Parel West',
#  'Madanpura',
#  'Madh',
#  'Mahalakshmi',
#  'Mahim',
#  'Malabar Hill',
#  'Malad East',
#  'Malad West',
#  'Marine Lines',
#  'Matunga East',
#  'Matunga West',
#  'Mazgaon',
#  'Midc Chakala Industrial Area',
#  'Mira Road',
#  'Mira Road East',
#  'Mulund East',
#  'Mulund West',
#  'Mumbai Central',
#  'Naigaon East',
#  'Nalasopara East',
#  'Nalasopara West',
#  'Oshiwara',
#  'Palghar',
#  'Parel',
#  'Parsi Colony',
#  'Pirojshanagar',
#  'Powai',
#  'Prabhadevi',
#  'Ramdev Park',
#  'Sakinaka',
#  'Santacruz East',
#  'Santacruz West',
#  'Sewri',
#  'Shanti Park',
#  'Sher E Punjab Colony',
#  'Siddharth Nagar',
#  'Sion',
#  'Sion East',
#  'Tardeo',
#  'Thane West',
#  'Tilak Nagar',
#  'Vasai East',
#  'Vasai West',
#  'Vikhroli East',
#  'Vikhroli West',
#  'Vile Parle East',
#  'Vile Parle West',
#  'Virar East',
#  'Virar West',
#  'Virar west',
#  'Wadala',
#  'Wadala East',
#  'Worli',
#  'Yari Road',
#  'others']
