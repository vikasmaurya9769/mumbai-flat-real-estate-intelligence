# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.svm import SVR

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor

# %%
df = pd.read_csv(R'E:\Mumbai Flat Real Estate Intelligence\datasets\mumbai_properties_post_feature_selection_v2.csv')

# %%
df.head()
# Out:
#    price  bedrooms  bathrooms balcony  property_age   major_location  \
# 0   0.17         1          1       2  New_property  Nalasopara West
# 1   0.18         1          1       0  New_property           others
# 2   0.18         1          1       2  New_property          Palghar
# 3   0.18         1          1       2  New_property          Palghar
# 4   0.18         1          2       1  New_property          Palghar
#
#    built_up_area furnishing_type
# 0          550.0       Furnished
# 1          665.0       Furnished
# 2          630.0       Furnished
# 3          630.0     Unfurnished
# 4          630.0       Furnished

# %%
df['furnishing_type'].value_counts()
# Out:
# furnishing_type
# Furnished      5453
# Unfurnished    4161
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (9614, 8)

# %%
df = df[df['major_location'] != 'Vakola']

# %%
df.shape
# Out:
# (9611, 8)

# %%
# df = df[df['price']<18]

# %%
# df.shape

# %%
X = df.drop(columns=['price'])
y = df['price']

# %%
# Applying the log1p transformation to the target variable
y_transformed = np.log1p(y)

# %% [markdown]
# ### Ordinal Encoding

# %%
columns_to_encode = ['major_location',  'property_age', 'balcony','furnishing_type']

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedrooms', 'bathrooms', 'built_up_area']),
        ('cat', OrdinalEncoder(), columns_to_encode)
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean(),scores.std()
# Out:
# (np.float64(0.7384415010872983), np.float64(0.013974063061669746))

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedrooms', 'bathrooms',
#                                                    'built_up_area']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['major_location',
#                                                    'property_age', 'balcony',
#                                                    'furnishing_type'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 1.0760850631621757

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_output
# Out:
# [['linear_reg', np.float64(0.7384415010872983), 1.0760850631621757],
#  ['svr', np.float64(0.7446173229027798), 1.0255749457664811],
#  ['ridge', np.float64(0.7384417618897658), 1.076046094685717],
#  ['LASSO', np.float64(0.018147290612791356), 1.907486662374778],
#  ['decision tree', np.float64(0.816650907385451), 0.7752304649481796],
#  ['random forest', np.float64(0.8966941473661858), 0.6545331534504111],
#  ['extra trees', np.float64(0.8567710270799027), 0.7438076593962171],
#  ['gradient boosting', np.float64(0.8800130263006383), 0.726844960814376],
#  ['adaboost', np.float64(0.7368657033531434), 1.0517563372463026],
#  ['mlp', np.float64(0.7693679150881154), 0.9511338593645579],
#  ['xgboost', np.float64(0.9236356664535151), 0.5670053339024663]]

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 10            xgboost  0.923636  0.567005
# 5       random forest  0.896694  0.654533
# 7   gradient boosting  0.880013  0.726845
# 6         extra trees  0.856771  0.743808
# 4       decision tree  0.816651  0.775230
# 9                 mlp  0.769368  0.951134
# 1                 svr  0.744617  1.025575
# 8            adaboost  0.736866  1.051756
# 2               ridge  0.738442  1.076046
# 0          linear_reg  0.738442  1.076085
# 3               LASSO  0.018147  1.907487

# %% [markdown]
# ### OHE

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedrooms', 'bathrooms', 'built_up_area']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first'),['major_location','property_age','furnishing_type'])
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean()
# Out:
# np.float64(0.9126758226051189)

# %%
scores.std()
# Out:
# np.float64(0.00556185924412332)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedrooms', 'bathrooms',
#                                                    'built_up_area']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['major_location',
#                                                    'property_age', 'balcony',
#                                                    'furnishing_type']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['major_location',
#                                                    'property_age',
#                                                    'furnishing_type'])])),
#                 ('regressor', LinearRegression())])

# %%
y_pred = pipeline.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 0.6368726471167551

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 6         extra trees  0.915880  0.562924
# 10            xgboost  0.924092  0.574965
# 9                 mlp  0.916419  0.578727
# 5       random forest  0.914391  0.579744
# 2               ridge  0.912170  0.636194
# 0          linear_reg  0.912676  0.636873
# 4       decision tree  0.860082  0.687293
# 7   gradient boosting  0.880752  0.713247
# 1                 svr  0.785682  0.963674
# 8            adaboost  0.739692  1.025411
# 3               LASSO  0.018147  1.907487

# %% [markdown]
# ### OneHotEncoding With PCA

# %%
# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedrooms', 'bathrooms', 'built_up_area']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),['major_location','property_age'])
    ], 
    remainder='passthrough'
)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('pca', PCA(n_components=0.95)),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean()
# Out:
# np.float64(0.020503307020318308)

# %%
scores.std()
# Out:
# np.float64(0.008235909844130708)

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('pca', PCA(n_components=0.95)),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 5       random forest  0.687293  1.076966
# 6         extra trees  0.651956  1.116563
# 4       decision tree  0.589933  1.228788
# 10            xgboost  0.613427  1.260955
# 7   gradient boosting  0.593137  1.307499
# 8            adaboost  0.241018  1.760136
# 1                 svr  0.071194  1.824727
# 9                 mlp  0.065813  1.861385
# 2               ridge  0.020503  1.905793
# 0          linear_reg  0.020503  1.905793
# 3               LASSO  0.018190  1.907461

# %% [markdown]
# ### Target Encoder

# %%
import category_encoders as ce

# %%
columns_to_encode = ['major_location', 'balcony', 'property_age', 'furnishing_type']

# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedrooms', 'bathrooms', 'built_up_area']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),['property_age']),
        ('target_enc', ce.TargetEncoder(), ['major_location'])
    ], 
    remainder='passthrough'
)

# %%
# !pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (2.9.0)
# Requirement already satisfied: numpy>=1.14.0 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from category_encoders) (2.3.5)
# Requirement already satisfied: pandas>=1.0.5 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from category_encoders) (2.3.3)
# Requirement already satisfied: patsy>=0.5.1 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: scikit-learn>=1.6.0 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from category_encoders) (1.7.2)
# Requirement already satisfied: scipy>=1.0.0 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from category_encoders) (1.16.3)
# Requirement already satisfied: statsmodels>=0.9.0 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from category_encoders) (0.14.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: six>=1.5 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in e:\mumbai flat real estate intelligence\mumbai_flat_env\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (25.0)

# %%
# Creating a pipeline
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# %%
# K-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')

# %%
scores.mean(),scores.std()
# Out:
# (np.float64(0.8907256650300992), np.float64(0.008092702807362219))

# %%
def scorer(model_name, model):
    
    output = []
    
    output.append(model_name)
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('regressor', model)
    ])
    
    # K-fold cross-validation
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    scores = cross_val_score(pipeline, X, y_transformed, cv=kfold, scoring='r2')
    
    output.append(scores.mean())
    
    X_train, X_test, y_train, y_test = train_test_split(X,y_transformed,test_size=0.2,random_state=42)
    
    pipeline.fit(X_train,y_train)
    
    y_pred = pipeline.predict(X_test)
    
    y_pred = np.expm1(y_pred)
    
    output.append(mean_absolute_error(np.expm1(y_test),y_pred))
    
    return output

# %%
model_dict = {
    'linear_reg':LinearRegression(),
    'svr':SVR(),
    'ridge':Ridge(),
    'LASSO':Lasso(),
    'decision tree': DecisionTreeRegressor(),
    'random forest':RandomForestRegressor(),
    'extra trees': ExtraTreesRegressor(),
    'gradient boosting': GradientBoostingRegressor(),
    'adaboost': AdaBoostRegressor(),
    'mlp': MLPRegressor(),
    'xgboost':XGBRegressor()
}

# %%
model_output = []
for model_name,model in model_dict.items():
    model_output.append(scorer(model_name, model))

# %%
model_df = pd.DataFrame(model_output, columns=['name','r2','mae'])

# %%
model_df.sort_values(['mae'])
# Out:
#                  name        r2       mae
# 10            xgboost  0.930499  0.539400
# 6         extra trees  0.925387  0.548835
# 5       random forest  0.927958  0.549359
# 7   gradient boosting  0.917957  0.591549
# 4       decision tree  0.878831  0.662793
# 9                 mlp  0.890929  0.673785
# 0          linear_reg  0.890726  0.700720
# 2               ridge  0.890727  0.700744
# 8            adaboost  0.857738  0.784237
# 1                 svr  0.862140  0.793409
# 3               LASSO  0.018147  1.907487

# %% [markdown]
# ### Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
df.head()
# Out:
#    price  bedrooms  bathrooms balcony  property_age   major_location  \
# 0   0.17         1          1       2  New_property  Nalasopara West
# 1   0.18         1          1       0  New_property           others
# 2   0.18         1          1       2  New_property          Palghar
# 3   0.18         1          1       2  New_property          Palghar
# 4   0.18         1          2       1  New_property          Palghar
#
#    built_up_area furnishing_type
# 0          550.0       Furnished
# 1          665.0       Furnished
# 2          630.0       Furnished
# 3          630.0     Unfurnished
# 4          630.0       Furnished

# %%
param_grid = {
    'regressor__n_estimators': [300, 400, 500],
    'regressor__max_depth': [None, 10, 20, 25, 30],
    'regressor__min_samples_split': [2, 5, 10],
    'regressor__min_samples_leaf': [1, 2, 4],
    'regressor__max_features': ['auto', 'sqrt'],
    'regressor__max_samples': [0.5, 0.75, 1.0]
}

# %%
columns_to_encode = [ 'balcony', 'furnishing_type']

# Creating a column transformer for preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['bedrooms', 'bathrooms', 'built_up_area']),
        ('cat', OrdinalEncoder(), columns_to_encode),
        ('cat1',OneHotEncoder(drop='first',sparse_output=False),['property_age']),
        ('target_enc', ce.TargetEncoder(), ['major_location'])
    ], 
    remainder='passthrough'
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor())
])

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# %%
search = GridSearchCV(pipeline, param_grid, cv=kfold, scoring='r2', n_jobs=-1, verbose=4)

# %%
search.fit(X, y_transformed)
# Out:
# Fitting 10 folds for each of 810 candidates, totalling 8100 fits
# e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\model_selection\_validation.py:516: FitFailedWarning:
# 4050 fits failed out of a total of 8100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1906 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\pipeline.py", line 663, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 2144 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\pipeline.py", line 663, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\model_selection\_search.py:1135: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.92429105 0.9245564  0.92470419
#  0.92330716 0.92318749 0.92324726 0.92027586 0.9203219  0.92031514
#  0.92126288 0.92147168 0.92152949 0.92121313 0.92111045 0.92121531
#  0.91869301 0.91889443 0.91887034 0.91650712 0.91673795 0.91676638
#  0.91676425 0.91670784 0.91672713 0.9160358  0.91622912 0.91632904
#  0.92517163 0.92540877 0.92544406 0.92476109 0.92509399 0.9248473
#  0.92246143 0.92239911 0.92247619 0.92352974 0.92364429 0.92356999
#  0.92304219 0.92307649 0.92333482 0.92112761 0.92105727 0.92122773
#  0.919028   0.91927211 0.91908241 0.91904745 0.91903872 0.91923258
#  0.91861985 0.91876675 0.91871479 0.92510604 0.92529744 0.92518904
#  0.92565442 0.92577804 0.92575327 0.92351073 0.92379877 0.9237798
#  0.92434073 0.92432975 0.92440771 0.92427795 0.92410557 0.92433796
#  0.92245779 0.92238522 0.92244933 0.92045745 0.92035393 0.9206456
#  0.9204212  0.92052197 0.9205494  0.92001223 0.92009441 0.92023083
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.91711449 0.91710549 0.91698568
#  0.91637712 0.9167586  0.91659039 0.91497119 0.91539101 0.9153445
#  0.91583262 0.91587421 0.91592083 0.91562417 0.91541163 0.91574172
#  0.91447483 0.9145507  0.914646   0.9135306  0.91348236 0.91358593
#  0.91353462 0.9136113  0.91368503 0.91337998 0.91309178 0.91325699
#  0.91758879 0.9176452  0.91790075 0.91700588 0.91723698 0.91740106
#  0.91619785 0.9163177  0.916238   0.91697241 0.91683642 0.91700383
#  0.91698358 0.91679725 0.91678208 0.91566794 0.91575863 0.91580829
#  0.91506787 0.91497657 0.91494264 0.91493513 0.91496915 0.915027
#  0.9147393  0.91473072 0.91483948 0.91821131 0.91818465 0.9181313
#  0.91798952 0.91780197 0.91780316 0.91697525 0.91688874 0.9167365
#  0.91730986 0.9174067  0.91741035 0.91732305 0.91737884 0.91730444
#  0.91641781 0.91631789 0.91655774 0.91565166 0.91579708 0.91578422
#  0.91591624 0.91558787 0.91588097 0.91555936 0.91554544 0.91560539
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.92466024 0.924637   0.92470927
#  0.92311636 0.92314771 0.92324254 0.92030329 0.92028291 0.92020174
#  0.9212081  0.92145767 0.92168121 0.92104908 0.92126325 0.92113093
#  0.91880355 0.91874645 0.91878177 0.9165799  0.91661972 0.91674262
#  0.91668553 0.91675267 0.91691145 0.91642033 0.91633497 0.91630694
#  0.92561164 0.92548558 0.9255875  0.92484247 0.92476421 0.92493341
#  0.92244769 0.9225816  0.92239721 0.92333043 0.92341938 0.92345181
#  0.92305526 0.92331232 0.92316993 0.92114771 0.92129776 0.92128026
#  0.91908076 0.91904876 0.91906258 0.9191448  0.91917056 0.91919723
#  0.91855191 0.91864266 0.91861996 0.92545839 0.92552359 0.92563131
#  0.92542379 0.92562883 0.92575905 0.92342746 0.92372981 0.92369412
#  0.92443998 0.92450101 0.92446655 0.92433517 0.92427568 0.92442013
#  0.92237702 0.92241754 0.92252697 0.92027652 0.92057651 0.9205624
#  0.92050062 0.92037821 0.9204671  0.92005972 0.92016846 0.92011069
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.92452207 0.92442702 0.92447129
#  0.92333136 0.92309118 0.92314815 0.92032978 0.92023468 0.9202953
#  0.92124039 0.92147836 0.92161016 0.92113866 0.92134212 0.92120286
#  0.91894723 0.91891716 0.9188294  0.9166023  0.91672527 0.91675493
#  0.9166514  0.91671442 0.91684601 0.91627199 0.91622563 0.91625834
#  0.92538038 0.92526138 0.92550507 0.9248614  0.92488683 0.92493717
#  0.92218328 0.92256472 0.92238319 0.92354074 0.92338144 0.92349004
#  0.92335854 0.92335935 0.92325001 0.92131458 0.92114519 0.92098749
#  0.91898169 0.91911391 0.91924761 0.91906242 0.91896926 0.91926892
#  0.9187179  0.91882575 0.91871165 0.92540523 0.92542651 0.92530906
#  0.92552748 0.92552906 0.92562031 0.92385925 0.92365581 0.92367056
#  0.9245091  0.9247002  0.924605   0.92400511 0.92446141 0.92427772
#  0.92228254 0.92252262 0.92247228 0.92046345 0.92066979 0.92059375
#  0.92049778 0.92038118 0.92050168 0.92028656 0.92003225 0.92016029
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.92441806 0.92462101 0.92452845
#  0.92308669 0.92325311 0.92313597 0.92025657 0.92044348 0.92032319
#  0.92147295 0.92149135 0.92141171 0.92117233 0.92108034 0.92113494
#  0.91893856 0.91884306 0.91882126 0.91666813 0.91683179 0.91663143
#  0.91661051 0.91648834 0.91657837 0.91611873 0.91607373 0.91644231
#  0.92516175 0.9254994  0.92548522 0.92492793 0.92497353 0.92501042
#  0.92224342 0.92242557 0.92252547 0.9236257  0.92329378 0.92353717
#  0.9230179  0.92312246 0.92324468 0.92114085 0.92116176 0.92118719
#  0.91894457 0.91909781 0.91918645 0.91902889 0.91922594 0.91912707
#  0.91874812 0.91880889 0.91879517 0.92514068 0.92503122 0.92528259
#  0.92567155 0.92550856 0.92556843 0.92385629 0.92379594 0.92362577
#  0.9244081  0.92440674 0.9246138  0.92421759 0.92433351 0.92433319
#  0.92265524 0.92241993 0.92250316 0.92044964 0.9204351  0.9205217
#  0.92038981 0.92040968 0.92063934 0.92024383 0.92012261 0.92026608]
#   warnings.warn(
# GridSearchCV(cv=KFold(n_splits=10, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['bedrooms',
#                                                                           'bathrooms',
#                                                                           'built_up_area']),
#                                                                         ('cat',
#                                                                          OrdinalEncoder(),
#                                                                          ['balcony',
#                                                                           'furnishing_type']),
#                                                                         ('cat1',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        sparse_output=False),
#                                                                          ['property_...
#                                                                          ['major_location'])])),
#                                        ('regressor', RandomForestRegressor())]),
#              n_jobs=-1,
#              param_grid={'regressor__max_depth': [None, 10, 20, 25, 30],
#                          'regressor__max_features': ['auto', 'sqrt'],
#                          'regressor__max_samples': [0.5, 0.75, 1.0],
#                          'regressor__min_samples_leaf': [1, 2, 4],
#                          'regressor__min_samples_split': [2, 5, 10],
#                          'regressor__n_estimators': [300, 400, 500]},
#              scoring='r2', verbose=4)

# %%
final_pipe = search.best_estimator_

# %%
search.best_params_
# Out:
# {'regressor__max_depth': None,
#  'regressor__max_features': 'sqrt',
#  'regressor__max_samples': 1.0,
#  'regressor__min_samples_leaf': 1,
#  'regressor__min_samples_split': 5,
#  'regressor__n_estimators': 400}

# %%
search.best_score_
# Out:
# np.float64(0.9257780424828891)

# %%
final_pipe.fit(X,y_transformed)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num', StandardScaler(),
#                                                   ['bedrooms', 'bathrooms',
#                                                    'built_up_area']),
#                                                  ('cat', OrdinalEncoder(),
#                                                   ['balcony',
#                                                    'furnishing_type']),
#                                                  ('cat1',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['property_age']),
#                                                  ('target_enc', TargetEncoder(),
#                                                   ['major_location'])])),
#                 ('regressor',
#                  RandomForestRegressor(max_features='sqrt', max_samples=1.0,
#                                        min_samples_split=5,
#                                        n_estimators=400))])

# %%
y_pred = final_pipe.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mean_absolute_error(np.expm1(y_test),y_pred)
# Out:
# 0.33188451599879715

# %% [markdown]
# best selected model

# %%
numeric_cols = ['bedrooms', 'bathrooms', 'built_up_area']
onehot_cols = ['balcony', 'property_age', 'furnishing_type']
target_cols = ['major_location']

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_cols),
        ('cat_onehot', OneHotEncoder(drop='first', sparse_output=False), onehot_cols),
        ('target', ce.TargetEncoder(), target_cols)
    ],
    remainder='drop'
)

# %%
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor())
])

# %%
param_grid = {
    'regressor__n_estimators': [100],
    'regressor__max_depth': [None, 10, 20, 25, 30],
    'regressor__min_samples_split': [2, 5, 10],
    'regressor__min_samples_leaf': [1, 2, 4],
    'regressor__max_features': ['auto', 'sqrt'],
    'regressor__max_samples': [0.5, 0.75, 1.0]
}

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

search = GridSearchCV(
    pipeline,
    param_grid,
    cv=kfold,
    scoring='r2',
    n_jobs=-1,
    verbose=4
)

# %%
search.fit(X, y_transformed)
# Out:
# Fitting 10 folds for each of 270 candidates, totalling 2700 fits
# e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\model_selection\_validation.py:516: FitFailedWarning:
# 1350 fits failed out of a total of 2700.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 675 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\pipeline.py", line 663, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 675 fits failed with the following error:
# Traceback (most recent call last):
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\pipeline.py", line 663, in fit
#     self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\base.py", line 471, in _validate_params
#     validate_parameter_constraints(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         self._parameter_constraints,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         self.get_params(deep=False),
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         caller_name=self.__class__.__name__,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\utils\_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
#     ...<2 lines>...
#     )
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# e:\Mumbai Flat Real Estate Intelligence\mumbai_flat_env\Lib\site-packages\sklearn\model_selection\_search.py:1135: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.92082104 0.91979135 0.91599983
#  0.91694382 0.91644558 0.91387265 0.91027606 0.91015536 0.91013134
#  0.92171751 0.92174985 0.91829614 0.91919088 0.91904763 0.91660772
#  0.91345766 0.91362923 0.91304752 0.92134656 0.92180835 0.91972796
#  0.92029916 0.92006153 0.91826134 0.91521535 0.91487677 0.91448042
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.90985017 0.90984016 0.9086046
#  0.90844014 0.90856266 0.90751054 0.9054329  0.90519424 0.90490097
#  0.91118868 0.91052567 0.90910911 0.90963337 0.91023039 0.90845161
#  0.9066114  0.90740915 0.90654734 0.91136297 0.91063585 0.90947189
#  0.91029258 0.90997732 0.90906755 0.9078358  0.90839792 0.90759924
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.92087641 0.91937411 0.91639704
#  0.91641448 0.9162279  0.91399383 0.9105229  0.91055402 0.90999228
#  0.92203076 0.92113503 0.91877517 0.91882133 0.91877414 0.91682204
#  0.91311096 0.91321716 0.91246937 0.92225158 0.92215402 0.92004207
#  0.92065193 0.92042073 0.91808597 0.91550163 0.9147246  0.91501355
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.92093566 0.91921186 0.91664183
#  0.9167489  0.91668606 0.91396512 0.91065954 0.91027401 0.91012212
#  0.92205805 0.92185103 0.9182308  0.91902291 0.91879548 0.9161086
#  0.91345264 0.91300609 0.91293999 0.92141403 0.92191235 0.91983014
#  0.9202979  0.91974401 0.91804643 0.91508295 0.91521034 0.91478421
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.92086376 0.9196527  0.91625235
#  0.91700759 0.91603585 0.91405906 0.91042109 0.91067423 0.91006376
#  0.92181105 0.92126194 0.91829255 0.91882468 0.91895151 0.91692591
#  0.91364565 0.9130628  0.913213   0.92140338 0.92188001 0.91988116
#  0.9203816  0.92035152 0.91817925 0.91523494 0.91482001 0.91449786]
#   warnings.warn(
# GridSearchCV(cv=KFold(n_splits=10, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          StandardScaler(),
#                                                                          ['bedrooms',
#                                                                           'bathrooms',
#                                                                           'built_up_area']),
#                                                                         ('cat_onehot',
#                                                                          OneHotEncoder(drop='first',
#                                                                                        sparse_output=False),
#                                                                          ['balcony',
#                                                                           'property_age',
#                                                                           'furnishing_type']),
#                                                                         ('target',
#                                                                          TargetEncoder(),
#                                                                          ['major_location'])])),
#                                        ('regressor', RandomForestRegressor())]),
#              n_jobs=-1,
#              param_grid={'regressor__max_depth': [None, 10, 20, 25, 30],
#                          'regressor__max_features': ['auto', 'sqrt'],
#                          'regressor__max_samples': [0.5, 0.75, 1.0],
#                          'regressor__min_samples_leaf': [1, 2, 4],
#                          'regressor__min_samples_split': [2, 5, 10],
#                          'regressor__n_estimators': [100]},
#              scoring='r2', verbose=4)

# %%
final_pipe = search.best_estimator_

# %%
y_pred = final_pipe.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
mae = mean_absolute_error(np.expm1(y_test), y_pred)

# %%
print("Best Params:", search.best_params_)
print("Best R2 Score:", search.best_score_)
print("MAE:", mean_absolute_error(np.expm1(y_test), y_pred))
# Out:
# Best Params: {'regressor__max_depth': 20, 'regressor__max_features': 'sqrt', 'regressor__max_samples': 1.0, 'regressor__min_samples_leaf': 1, 'regressor__min_samples_split': 2, 'regressor__n_estimators': 100}
# Best R2 Score: 0.9222515830851667
# MAE: 0.2480666778881939

# %% [markdown]
# ### exporting pkl

# %%
import pickle

with open("pipeline.pkl", "wb") as file:
    pickle.dump(final_pipe, file)

# %%
with open('df.pkl', 'wb') as file:
    pickle.dump(X, file)

# %%
X
# Out:
#       bedrooms  bathrooms balcony    property_age   major_location  \
# 0            1          1       2    New_property  Nalasopara West
# 1            1          1       0    New_property           others
# 2            1          1       2    New_property          Palghar
# 3            1          1       2    New_property          Palghar
# 4            1          2       1    New_property          Palghar
# ...        ...        ...     ...             ...              ...
# 9609         5          5       0             Old     Malabar Hill
# 9610         5          5       0         Mid Age     Malabar Hill
# 9611         5          6       1             Old     Malabar Hill
# 9612         6          4       3         Mid Age      Lower Parel
# 9613         4          4       2  Relatively New     Malabar Hill
#
#       built_up_area furnishing_type
# 0             550.0       Furnished
# 1             665.0       Furnished
# 2             630.0       Furnished
# 3             630.0     Unfurnished
# 4             630.0       Furnished
# ...             ...             ...
# 9609         3699.0     Unfurnished
# 9610         3181.0       Furnished
# 9611         2850.0       Furnished
# 9612         5042.0       Furnished
# 9613         2917.0     Unfurnished
#
# [9611 rows x 7 columns]

# %%
X.shape
# Out:
# (9611, 7)

# %%
df.to_csv('mumbai_properties_final.csv', index=False)

# %% [markdown]
# ### Trying out the predictions

# %%
X.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'balcony', 'property_age', 'major_location',
#        'built_up_area', 'furnishing_type'],
#       dtype='object')

# %%
X.iloc[0].values
# Out:
# array([np.int64(1), np.int64(1), '2', 'New_property', 'Nalasopara West',
#        np.float64(550.0), 'Furnished'], dtype=object)

# %%
data = [[ 2, 2, '0', 'Mid Age', 'Mulund West', 650,  'Unfurnished']]
columns = ['bedrooms', 'bathrooms', 'balcony', 'property_age', 'major_location',
       'built_up_area',  'furnishing_type']

# Convert to DataFrame
one_df = pd.DataFrame(data, columns=columns)

one_df
# Out:
#    bedrooms  bathrooms balcony property_age major_location  built_up_area  \
# 0         2          2       0      Mid Age    Mulund West            650
#
#   furnishing_type
# 0     Unfurnished

# %%
np.expm1(final_pipe.predict(one_df))
# Out:
# array([1.75148518])

# %%
X.dtypes
# Out:
# bedrooms             int64
# bathrooms            int64
# balcony             object
# property_age        object
# major_location      object
# built_up_area      float64
# furnishing_type     object
# dtype: object

# %%
sorted(X['major_location'].unique().tolist())
# Out:
# ['Agripada',
#  'Andheri East',
#  'Andheri West',
#  'Bandra East',
#  'Bandra West',
#  'Bhandup East',
#  'Bhandup West',
#  'Bhayandar East',
#  'Bhayandar West',
#  'Bhoiwada',
#  'Boisar',
#  'Bolinj',
#  'Borivali East',
#  'Borivali West',
#  'Byculla',
#  'Chakala',
#  'Chembur',
#  'Chikhal Dongari',
#  'Churchgate',
#  'Colaba',
#  'Cuffe Parade',
#  'Cumballa Hill',
#  'Dadar East',
#  'Dadar West',
#  'Dahisar',
#  'Dahisar East',
#  'Dahisar West',
#  'Dattapada',
#  'Deonar',
#  'Evershine Nagar',
#  'Gandhi Nagar',
#  'Ghatkopar East',
#  'Ghatkopar West',
#  'Girgaon',
#  'Goregaon',
#  'Goregaon East',
#  'Goregaon West',
#  'Govandi',
#  'Hindu Colony',
#  'Hmpl Surya Nagar',
#  'Jogeshwari East',
#  'Jogeshwari West',
#  'Juhu',
#  'Juhu Scheme',
#  'Jvpd Scheme',
#  'Kala Nagar',
#  'Kamathipura',
#  'Kanchpada',
#  'Kandivali East',
#  'Kandivali West',
#  'Kanjurmarg East',
#  'Kanjurmarg West',
#  'Kashimira',
#  'Khar West',
#  'Kherwadi',
#  'Kurla East',
#  'Kurla West',
#  'Lower Parel',
#  'Lower Parel East',
#  'Lower Parel West',
#  'Madanpura',
#  'Madh',
#  'Mahalakshmi',
#  'Mahim',
#  'Malabar Hill',
#  'Malad East',
#  'Malad West',
#  'Marine Lines',
#  'Matunga East',
#  'Matunga West',
#  'Mazgaon',
#  'Midc Chakala Industrial Area',
#  'Mira Road',
#  'Mira Road East',
#  'Mulund East',
#  'Mulund West',
#  'Mumbai Central',
#  'Naigaon East',
#  'Nalasopara East',
#  'Nalasopara West',
#  'Oshiwara',
#  'Palghar',
#  'Parel',
#  'Parsi Colony',
#  'Pirojshanagar',
#  'Powai',
#  'Prabhadevi',
#  'Ramdev Park',
#  'Sakinaka',
#  'Santacruz East',
#  'Santacruz West',
#  'Sewri',
#  'Shanti Park',
#  'Sher E Punjab Colony',
#  'Siddharth Nagar',
#  'Sion',
#  'Sion East',
#  'Tardeo',
#  'Thane West',
#  'Tilak Nagar',
#  'Vasai East',
#  'Vasai West',
#  'Vikhroli East',
#  'Vikhroli West',
#  'Vile Parle East',
#  'Vile Parle West',
#  'Virar East',
#  'Virar West',
#  'Virar west',
#  'Wadala',
#  'Wadala East',
#  'Worli',
#  'Yari Road',
#  'others']
